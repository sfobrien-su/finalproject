# %%
# !pip install spotipy

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id='2c3a188fdec642c991665190794c740e', client_secret='d9d2b595a9a34016b11842d84bb08774', proxies=None)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
playlist = sp.user_playlist(user = 'flzz44ta8js72hwm0w94j80bc', playlist_id = '1KNl4AYfgZtOVm9KHkhPTF', fields = None)
playlist2 = sp.user_playlist(user = 'flzz44ta8js72hwm0w94j80bc', playlist_id = '2ngGaFfD9KLjRrfnC4to0y', fields = None)
playlist3 = sp.user_playlist(user = 'flzz44ta8js72hwm0w94j80bc', playlist_id = '6ISodKCXQdYYEEJNTYnb3G', fields = None)
playlist4 = sp.user_playlist(user = 'flzz44ta8js72hwm0w94j80bc', playlist_id = '3BU1b177A4HBjAUonBfWUO', fields = None)
print(playlist)
print(playlist2)
print(playlist3)
print(playlist4)
# Out:
# {'collaborative': False, 'description': "Packed with all the best songs of 2019. Today's most streamed tracks and top songs - worldwide! Pop, Dance, Hip-Hop and Latin hot hits! Cover: Coldplay", 'external_urls': {'spotify': 'https://open.spotify.com/playlist/1KNl4AYfgZtOVm9KHkhPTF'}, 'followers': {'href': None, 'total': 67833}, 'href': 'https://api.spotify.com/v1/playlists/1KNl4AYfgZtOVm9KHkhPTF', 'id': '1KNl4AYfgZtOVm9KHkhPTF', 'images': [{'height': None, 'url': 'https://pl.scdn.co/images/pl/default/5d2fe34d3639ff0e63844fd15ff154a9902386cf', 'width': None}], 'name': 'Global Top 50 | 2019 Hits', 'owner': {'display_name': 'Topsify', 'external_urls': {'spotify': 'https://open.spotify.com/user/topsify'}, 'href': 'https://api.spotify.com/v1/users/topsify', 'id': 'topsify', 'type': 'user', 'uri': 'spotify:user:topsify'}, 'primary_color': None, 'public': True, 'snapshot_id': 'OTQwLDY5MzIxNGI0YWY2MjUwNjU5ZTVkMGY3ZDc2Yzk5MWFiZTk3ZjI2MDY=', 'tracks': {'href': 'https://api.spotify.com/v1/playl
# ...

# %%
#got list of 50 songs
song_ids = []
for song in playlist["tracks"]["items"]:
    song_ids.append(song["track"]["id"])
print(song_ids)
# Out:
# ['4QPEwDdOMhY7rNS05mTyMR', '6WrI0LAC5M1Rw2MnX2ZvEg', '4vUmTMuQqjdnvlZmAH61Qk', '2XU0oxnq2qxCpomAAuJY8K', '07Oz5StQ7GRoygNLaXs2pd', '696DnlkuDOXcMAnKlTgXXK', '5bvnqVuq7UFl0txSlHpsfS', '6YQlCOZnlFmqeciAh58fDE', '3VyjsVV24RmBIbWJAeUJNu', '2wrJq5XKLnmhRXHIAf9xBa', '4GGSmoTmc5LClrowB4SmEw', '6moU77g9RQyMzHNuKEaQKq', '21jGcNKet2qwijlDFuPiPb', '70eFcWOvlMObDhURTqT4Fv', '0qc4QlcCxVTGyShurEv1UU', '322tcqPhma7F6hfCeLisx0', '2GdxQw8NwoeH8tKySg6nym', '51Fjme0JiitpyXKuyQiCDo', '5EjNEaFiXpddlZglT4RoWi', '4sWuPniHClkInYAnzXAYUF', '0hVXuCcriWRGvwMV1r5Yn9', '35MKhw2YBKApmD7fAnPERC', '6mf7BNgXs8JipPr2QILnyN', '2Fxmhks0bxGSBdJ92vM42m', '7jHJ2MzIKO1kIMxGamKRKn', '6EOKwHETwSkZ9gW2b6ASE0', '7qEHsqek33rTcFNT9PFqLf', '1i3z3GR1JtLswOSJNO0BQw', '2SXJE0Afzf52dX1OD9BMsC', '7cohRKBHDeIVhPGlU9toqE', '6dNaImQJF0Y1wrjMBy4KLz', '2tnVG71enUj33Ic2nFN6kZ', '2qxmye6gAegTMjLKEBoR3d', '6Ngm2VhQna3DJGSYf5ePVG', '6u7jPi22kF8CTQ3rb9DHE7', '0kPIrtp3youhat1nkmPACX', '7DcvwMAiqKJQD1rrdfxSDx', '1HimGOB6BjOaCQYMIF1xtU', '2oeYjGXq
# ...

# %%
song_ids2 = []
for song in playlist2["tracks"]["items"]:
    song_ids2.append(song["track"]["id"])
print(song_ids2)
# Out:
# ['50kpGaPAhYJ3sGmk6vplg0', '09CtPGIpYB4BrO8qb1RGsF', '0ENSn4fwAbCGeFGVUbXEU3', '4B0JvthVoAAuygILe3n4Bs', '3zkWCteF82vJwv0hRLba76', '6nmz4imkDcmtwMjocAzFSx', '0tiLDOYgY2n3qLFvq7c1QZ', '6RsWqX8zABZLhZydXxEFOm', '5tf1VVWniHgryyumXyJM7w', '7gBj0VgcuAgkXkiRRYvSmK', '69uxyAqqPIsUyTO8txoP2M', '40MkEbKzuSW9ET6HBngqnK', '4nS1sut0R2mgmFitKIShVe', '40YcuQysJ0KlGQTeGUosTC', '66hayvUbTotekKU3H4ta1f', '3vv9phIu6Y1vX3jcqaGz5Z', '6splO3UF8hSmK33y5fJTNk', '25khomWgBVamSdKw7hzm3l', '22mek4IiqubGD9ctzxc69s', '0r4SsYcwvd8URat6AS2m6f', '1BZG99C7Co1r6QUC3zaS59', '1cdzfFjEbUbgTm5nv3FgXR', '1wYZZtamWTQAoj8B812uKQ', '7x5xYW5W42OGPAdHUyyguy', '3NLnwwAQbbFKcEcV8hDItk', '1brwdYwjltrJo7WHpIvbYt', '1LoriJC05IrHIDwj3q0KC1', '1HNkqx9Ahdgi1Ixy2xkKkL', '3CRDbSIZ4r5MsZ0YwxuEkn', '7M9t7BCy51ITF8IMyiemzk', '0SNIAtRCPVVLoGEPcuHSIc', '2vDT1uU6hZgdp3PbWGr0Xy', '53Y0kdCa1CZ9gRqEuknfwy', '7fPHfBCyKE3aVCBjE4DAvl', '27GmP9AWRs744SzKcpJsTZ', '6WLS56xiRrXjSm9RSdL3zD', '34gCuhDGsG4bRPIf9bb02f', '2K87XMYnUMqLcX3zvtAF4G', '5XfywqPX
# ...

# %%
song_ids3 = []
for song in playlist3["tracks"]["items"]:
    song_ids3.append(song["track"]["id"])
print(song_ids3)
# Out:
# ['0XzkemXSiXJa7VgDFPfU4S', '6g1NlCpW7fgqDnWbCCDrHl', '5GjnIpUlLGEIYk052ISOw9', '2Foc5Q5nqNiosCNqttzHof', '3bidbhpOYeV4knp8AIu8Xn', '1mKXFLRA179hdOWQBwUk9e', '0GNI8K3VATWBABQFAzBAYe', '6NPVjNh8Jhru9xOmyQigds', '1CmUZGtH29Kx36C1Hleqlz', '09TcIuH1ZO7i4vicWKoaN2', '3bDGwl0X3EjQmIyFD1uif5', '1RTVBt6wWtWs2qiRVnlzLM', '4DMPn1rEujpIJIvjy9HKV8', '1TWfkGrhF7ob0nwB2M6knb', '3yvZ1VUso9Xi7EvIyLaj4o', '30BsewEJZPxfuLNAlZPFje', '52gvlDnre9craz9dKGObp8', '5StvAhgmgCOpCPHHNfS8bx', '5l3CML2OnzfNs5RfVgbcLt', '0nJW01T7XtvILxQgC5J7Wh', '1jdNcAD8Ir58RlsdGjJJdx', '7DFNE7NO0raLIUbgzY2rzm', '0Hf4aIJpsN4Os2f0y0VqWl', '4rHZZAmHpZrA3iH5zx8frV', '21YWbLRtyRJl9PAtxUkDEf', '3zKST4nk4QJE77oLjUZ0Ng', '2bNrvWD9d5Zn9tS8XvcaMk', '4eLSCSELtKxZwXnFbNLXT5', '3VZQshi4COChhXaz7cLP02', '6O20JhBJPePEkBdrB5sqRx', '2GgxS8bUT5G25QJTsfSv0R', '3jZomvOBa5qfTo5HkqI1p5', '3JvKfv6T31zO0ini8iNItO', '55h7vJchibLdUkxdlX3fK7', '3w3y8KPTfNeOKPiqUTakBh', '2vwlzO0Qp8kfEtzTsCXfyE', '73ACPH1HBxaFvjbPqvs5O2', '5U8hKxSaDXB8cVeLFQjvwx', '4w47YE9r
# ...

# %%
song_ids4 = []
for song in playlist4["tracks"]["items"]:
    song_ids4.append(song["track"]["id"])
print(song_ids4)
# Out:
# ['3hwQhakFwm9soLEBnSDH17', '74ZovzRxHBvCq5yIwe8boh', '2qTy3hGSbxoSenKmlKGHFw', '0jqFM7E9z1PLYtPVCuFwAi', '7AclP0W2jy6yrbvBiC4prQ', '0zLClc0emc6qUeV1p5nc99', '2eg2gvPXuwZ9FyrPaLgrXi', '6Eh8SvUdMWJGZvTR8t0174', '4uQ7wYsuL0DryknoDc11Hk', '3t844ssjXzE9M3SDtUxTI4', '4fUeGY1jGkgtx11tuqbDlq', '0gBrJS89BL4r8rqjDEzbtp', '1a1MJ64D5ZIdzVWJ3uGaLy', '1xuy0LhOqyRErM3PTjQfHm', '2HbKqm4o0w5wEeEFXm2sD4', '6MEDfjHxnVNcYmHe3mM6L2', '0dicUxKmYKYFyIfiIo9vTm', '7D51nXZIGAFnYWME95dQpd', '0q488eAgvoMCrkYSv70TRh', '2QB1chgLUjo4K5JwODVue1', '6tS3XVuOyu10897O3ae7bi', '61LtVmmkGr8P9I2tSPvdpf', '5Q0Nhxo0l2bP3pNjpGJwV1', '1ouHuqrpM2NlyOSoQqZvSP', '3Jz9xQfj5UHPeGH7l9RWRL', '54yKcXhzyC8Um5CLELf6l9', '71CNRwNRFUbp0JZfieCEej', '1yKu2MhpwzDXXH2tzG6xoa', '0bWKniFVup1UYgoZww89Vp', '0sAIljILdEo8Ku4tPLQ7dF', '7DZ8dV4MqONQn8IcSTHdxh', '6aLmvz0CPeCNHCXK2H5QIC', '5bVOX6eyHsML2sB4aMlZEi', '7xMklu8GE39dYZBWJMxrBU', '6TU0zW9qJaG53vSa1R57qb', '40L8L7344pPMCjlZc19RQU', '64003fAAbyRqenrDKa6BdI', '4aiGuq8owmdrU9WKZNVfCe', '6HadZejJ
# ...

# %%
#analyze songs
analysis = []
analysis = sp.audio_features(tracks = song_ids)
print(analysis)
# Out:
# [{'danceability': 0.817, 'energy': 0.781, 'key': 7, 'loudness': -4.178, 'mode': 0, 'speechiness': 0.112, 'acousticness': 0.00838, 'instrumentalness': 5.21e-06, 'liveness': 0.123, 'valence': 0.359, 'tempo': 104.0, 'type': 'audio_features', 'id': '4QPEwDdOMhY7rNS05mTyMR', 'uri': 'spotify:track:4QPEwDdOMhY7rNS05mTyMR', 'track_href': 'https://api.spotify.com/v1/tracks/4QPEwDdOMhY7rNS05mTyMR', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QPEwDdOMhY7rNS05mTyMR', 'duration_ms': 216707, 'time_signature': 4}, {'danceability': 0.794, 'energy': 0.793, 'key': 11, 'loudness': -4.521, 'mode': 0, 'speechiness': 0.0842, 'acousticness': 0.0125, 'instrumentalness': 0, 'liveness': 0.0952, 'valence': 0.677, 'tempo': 123.941, 'type': 'audio_features', 'id': '6WrI0LAC5M1Rw2MnX2ZvEg', 'uri': 'spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg', 'track_href': 'https://api.spotify.com/v1/tracks/6WrI0LAC5M1Rw2MnX2ZvEg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WrI0LAC5M1Rw2MnX2ZvEg', 'dura
# ...

# %%
analysis2 = []
analysis2 = sp.audio_features(tracks = song_ids2)
print(analysis2)
# Out:
# [{'danceability': 0.609, 'energy': 0.378, 'key': 4, 'loudness': -9.828, 'mode': 1, 'speechiness': 0.438, 'acousticness': 0.835, 'instrumentalness': 0, 'liveness': 0.28, 'valence': 0.515, 'tempo': 100.418, 'type': 'audio_features', 'id': '50kpGaPAhYJ3sGmk6vplg0', 'uri': 'spotify:track:50kpGaPAhYJ3sGmk6vplg0', 'track_href': 'https://api.spotify.com/v1/tracks/50kpGaPAhYJ3sGmk6vplg0', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50kpGaPAhYJ3sGmk6vplg0', 'duration_ms': 233720, 'time_signature': 4}, {'danceability': 0.654, 'energy': 0.76, 'key': 0, 'loudness': -3.669, 'mode': 0, 'speechiness': 0.045, 'acousticness': 0.0797, 'instrumentalness': 0, 'liveness': 0.299, 'valence': 0.41, 'tempo': 99.945, 'type': 'audio_features', 'id': '09CtPGIpYB4BrO8qb1RGsF', 'uri': 'spotify:track:09CtPGIpYB4BrO8qb1RGsF', 'track_href': 'https://api.spotify.com/v1/tracks/09CtPGIpYB4BrO8qb1RGsF', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09CtPGIpYB4BrO8qb1RGsF', 'duration_ms': 2007
# ...

# %%
analysis3 = []
analysis3 = sp.audio_features(tracks = song_ids3)
print(analysis3)
# Out:
# [{'danceability': 0.862, 'energy': 0.503, 'key': 7, 'loudness': -7.703, 'mode': 1, 'speechiness': 0.0494, 'acousticness': 0.00453, 'instrumentalness': 1.87e-05, 'liveness': 0.0761, 'valence': 0.863, 'tempo': 119.998, 'type': 'audio_features', 'id': '0XzkemXSiXJa7VgDFPfU4S', 'uri': 'spotify:track:0XzkemXSiXJa7VgDFPfU4S', 'track_href': 'https://api.spotify.com/v1/tracks/0XzkemXSiXJa7VgDFPfU4S', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XzkemXSiXJa7VgDFPfU4S', 'duration_ms': 263053, 'time_signature': 4}, {'danceability': 0.532, 'energy': 0.783, 'key': 2, 'loudness': -5.697, 'mode': 1, 'speechiness': 0.0523, 'acousticness': 0.0038, 'instrumentalness': 0.0012, 'liveness': 0.161, 'valence': 0.643, 'tempo': 124.08, 'type': 'audio_features', 'id': '6g1NlCpW7fgqDnWbCCDrHl', 'uri': 'spotify:track:6g1NlCpW7fgqDnWbCCDrHl', 'track_href': 'https://api.spotify.com/v1/tracks/6g1NlCpW7fgqDnWbCCDrHl', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6g1NlCpW7fgqDnWbCCDrHl',
# ...

# %%
analysis4 = []
analysis4 = sp.audio_features(tracks = song_ids4)
print(analysis4)
# Out:
# [{'danceability': 0.404, 'energy': 0.298, 'key': 9, 'loudness': -12.986, 'mode': 0, 'speechiness': 0.0304, 'acousticness': 0.912, 'instrumentalness': 0.228, 'liveness': 0.0996, 'valence': 0.315, 'tempo': 78.815, 'type': 'audio_features', 'id': '3hwQhakFwm9soLEBnSDH17', 'uri': 'spotify:track:3hwQhakFwm9soLEBnSDH17', 'track_href': 'https://api.spotify.com/v1/tracks/3hwQhakFwm9soLEBnSDH17', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3hwQhakFwm9soLEBnSDH17', 'duration_ms': 577199, 'time_signature': 4}, {'danceability': 0.589, 'energy': 0.57, 'key': 1, 'loudness': -9.54, 'mode': 1, 'speechiness': 0.361, 'acousticness': 0.0456, 'instrumentalness': 1.51e-06, 'liveness': 0.137, 'valence': 0.441, 'tempo': 136.203, 'type': 'audio_features', 'id': '74ZovzRxHBvCq5yIwe8boh', 'uri': 'spotify:track:74ZovzRxHBvCq5yIwe8boh', 'track_href': 'https://api.spotify.com/v1/tracks/74ZovzRxHBvCq5yIwe8boh', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74ZovzRxHBvCq5yIwe8boh', 'dur
# ...

# %%
for d in analysis:
    print(d.values())
# Out:
# dict_values([0.817, 0.781, 7, -4.178, 0, 0.112, 0.00838, 5.21e-06, 0.123, 0.359, 104.0, 'audio_features', '4QPEwDdOMhY7rNS05mTyMR', 'spotify:track:4QPEwDdOMhY7rNS05mTyMR', 'https://api.spotify.com/v1/tracks/4QPEwDdOMhY7rNS05mTyMR', 'https://api.spotify.com/v1/audio-analysis/4QPEwDdOMhY7rNS05mTyMR', 216707, 4])
# dict_values([0.794, 0.793, 11, -4.521, 0, 0.0842, 0.0125, 0, 0.0952, 0.677, 123.941, 'audio_features', '6WrI0LAC5M1Rw2MnX2ZvEg', 'spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg', 'https://api.spotify.com/v1/tracks/6WrI0LAC5M1Rw2MnX2ZvEg', 'https://api.spotify.com/v1/audio-analysis/6WrI0LAC5M1Rw2MnX2ZvEg', 183290, 4])
# dict_values([0.857, 0.621, 9, -6.376, 0, 0.0824, 0.148, 0, 0.0865, 0.668, 97.986, 'audio_features', '4vUmTMuQqjdnvlZmAH61Qk', 'spotify:track:4vUmTMuQqjdnvlZmAH61Qk', 'https://api.spotify.com/v1/tracks/4vUmTMuQqjdnvlZmAH61Qk', 'https://api.spotify.com/v1/audio-analysis/4vUmTMuQqjdnvlZmAH61Qk', 204467, 4])
# ...

# %%
for d in analysis2:
    print(d.values())
# Out:
# dict_values([0.609, 0.378, 4, -9.828, 1, 0.438, 0.835, 0, 0.28, 0.515, 100.418, 'audio_features', '50kpGaPAhYJ3sGmk6vplg0', 'spotify:track:50kpGaPAhYJ3sGmk6vplg0', 'https://api.spotify.com/v1/tracks/50kpGaPAhYJ3sGmk6vplg0', 'https://api.spotify.com/v1/audio-analysis/50kpGaPAhYJ3sGmk6vplg0', 233720, 4])
# dict_values([0.654, 0.76, 0, -3.669, 0, 0.045, 0.0797, 0, 0.299, 0.41, 99.945, 'audio_features', '09CtPGIpYB4BrO8qb1RGsF', 'spotify:track:09CtPGIpYB4BrO8qb1RGsF', 'https://api.spotify.com/v1/tracks/09CtPGIpYB4BrO8qb1RGsF', 'https://api.spotify.com/v1/audio-analysis/09CtPGIpYB4BrO8qb1RGsF', 200787, 4])
# dict_values([0.481, 0.451, 5, -6.095, 0, 0.0347, 0.336, 0, 0.0872, 0.289, 157.966, 'audio_features', '0ENSn4fwAbCGeFGVUbXEU3', 'spotify:track:0ENSn4fwAbCGeFGVUbXEU3', 'https://api.spotify.com/v1/tracks/0ENSn4fwAbCGeFGVUbXEU3', 'https://api.spotify.com/v1/audio-analysis/0ENSn4fwAbCGeFGVUbXEU3', 295493, 4])
# ...

# %%
for d in analysis3:
    print(d.values())
# Out:
# dict_values([0.862, 0.503, 7, -7.703, 1, 0.0494, 0.00453, 1.87e-05, 0.0761, 0.863, 119.998, 'audio_features', '0XzkemXSiXJa7VgDFPfU4S', 'spotify:track:0XzkemXSiXJa7VgDFPfU4S', 'https://api.spotify.com/v1/tracks/0XzkemXSiXJa7VgDFPfU4S', 'https://api.spotify.com/v1/audio-analysis/0XzkemXSiXJa7VgDFPfU4S', 263053, 4])
# dict_values([0.532, 0.783, 2, -5.697, 1, 0.0523, 0.0038, 0.0012, 0.161, 0.643, 124.08, 'audio_features', '6g1NlCpW7fgqDnWbCCDrHl', 'spotify:track:6g1NlCpW7fgqDnWbCCDrHl', 'https://api.spotify.com/v1/tracks/6g1NlCpW7fgqDnWbCCDrHl', 'https://api.spotify.com/v1/audio-analysis/6g1NlCpW7fgqDnWbCCDrHl', 247427, 4])
# dict_values([0.552, 0.831, 8, -5.217, 1, 0.0298, 0.0391, 2.93e-06, 0.0632, 0.144, 129.889, 'audio_features', '5GjnIpUlLGEIYk052ISOw9', 'spotify:track:5GjnIpUlLGEIYk052ISOw9', 'https://api.spotify.com/v1/tracks/5GjnIpUlLGEIYk052ISOw9', 'https://api.spotify.com/v1/audio-analysis/5GjnIpUlLGEIYk052ISOw9', 204360, 5])
# ...

# %%
for d in analysis4:
    print(d.values())
# Out:
# dict_values([0.404, 0.298, 9, -12.986, 0, 0.0304, 0.912, 0.228, 0.0996, 0.315, 78.815, 'audio_features', '3hwQhakFwm9soLEBnSDH17', 'spotify:track:3hwQhakFwm9soLEBnSDH17', 'https://api.spotify.com/v1/tracks/3hwQhakFwm9soLEBnSDH17', 'https://api.spotify.com/v1/audio-analysis/3hwQhakFwm9soLEBnSDH17', 577199, 4])
# dict_values([0.589, 0.57, 1, -9.54, 1, 0.361, 0.0456, 1.51e-06, 0.137, 0.441, 136.203, 'audio_features', '74ZovzRxHBvCq5yIwe8boh', 'spotify:track:74ZovzRxHBvCq5yIwe8boh', 'https://api.spotify.com/v1/tracks/74ZovzRxHBvCq5yIwe8boh', 'https://api.spotify.com/v1/audio-analysis/74ZovzRxHBvCq5yIwe8boh', 151027, 4])
# dict_values([0.527, 0.716, 5, -6.029, 0, 0.0616, 0.0698, 8.71e-05, 0.0737, 0.331, 99.426, 'audio_features', '2qTy3hGSbxoSenKmlKGHFw', 'spotify:track:2qTy3hGSbxoSenKmlKGHFw', 'https://api.spotify.com/v1/tracks/2qTy3hGSbxoSenKmlKGHFw', 'https://api.spotify.com/v1/audio-analysis/2qTy3hGSbxoSenKmlKGHFw', 281347, 4])
# ...

# %%
danceability_index = []
for d in analysis:
    danceability_value = d['danceability']
    danceability_index.append(danceability_value)
print(danceability_index)
# Out:
# [0.817, 0.794, 0.857, 0.824, 0.668, 0.621, 0.866, 0.503, 0.656, 0.654, 0.636, 0.732, 0.695, 0.64, 0.59, 0.806, 0.664, 0.843, 0.654, 0.787, 0.798, 0.547, 0.503, 0.701, 0.534, 0.745, 0.501, 0.394, 0.808, 0.665, 0.701, 0.882, 0.652, 0.556, 0.878, 0.499, 0.796, 0.614, 0.711, 0.719, 0.622, 0.596, 0.592, 0.695, 0.579, 0.693, 0.743, 0.868, 0.889, 0.542]

# %%
danceability_index2 = []
for d in analysis2:
    danceability_value = d['danceability']
    danceability_index2.append(danceability_value)
print(danceability_index2)
# Out:
# [0.609, 0.654, 0.481, 0.845, 0.746, 0.896, 0.723, 0.702, 0.636, 0.648, 0.638, 0.747, 0.702, 0.757, 0.432, 0.713, 0.669, 0.356, 0.738, 0.694, 0.672, 0.672, 0.376, 0.509, 0.647, 0.589, 0.811, 0.614, 0.734, 0.682, 0.361, 0.765, 0.599, 0.48, 0.852, 0.583, 0.781, 0.73, 0.605, 0.782, 0.63, 0.746, 0.669, 0.616, 0.775, 0.856, 0.618, 0.777, 0.765, 0.679]

# %%
danceability_index3 = []
for d in analysis3:
    danceability_value = d['danceability']
    danceability_index3.append(danceability_value)
print(danceability_index3)
# Out:
# [0.862, 0.532, 0.552, 0.794, 0.641, 0.778, 0.621, 0.652, 0.781, 0.733, 0.56, 0.646, 0.77, 0.675, 0.636, 0.63, 0.754, 0.817, 0.76, 0.612, 0.685, 0.509, 0.673, 0.574, 0.534, 0.545, 0.509, 0.507, 0.714, 0.564, 0.559, 0.489, 0.445, 0.874, 0.726, 0.53, 0.673, 0.784, 0.752, 0.716, 0.794, 0.72, 0.422, 0.485, 0.692, 0.688, 0.723, 0.679, 0.651, 0.514]

# %%
danceability_index4 = []
for d in analysis4:
    danceability_value = d['danceability']
    danceability_index4.append(danceability_value)
print(danceability_index4)
# Out:
# [0.404, 0.589, 0.527, 0.509, 0.61, 0.508, 0.436, 0.926, 0.925, 0.448, 0.614, 0.419, 0.452, 0.724, 0.716, 0.479, 0.548, 0.811, 0.512, 0.607, 0.791, 0.846, 0.652, 0.807, 0.44, 0.688, 0.546, 0.693, 0.531, 0.486, 0.505, 0.611, 0.528, 0.434, 0.525, 0.427, 0.736, 0.758, 0.785, 0.464, 0.799, 0.585, 0.521, 0.849, 0.175, 0.798]

# %%
energy_index = []
for d in analysis:
    energy_value = d['energy']
    energy_index.append(energy_value)
print(energy_index)
# Out:
# [0.781, 0.793, 0.621, 0.588, 0.892, 0.601, 0.53, 0.808, 0.614, 0.63, 0.661, 0.463, 0.762, 0.648, 0.642, 0.558, 0.831, 0.391, 0.812, 0.713, 0.675, 0.795, 0.596, 0.425, 0.621, 0.642, 0.405, 0.718, 0.856, 0.434, 0.789, 0.78, 0.557, 0.668, 0.619, 0.578, 0.586, 0.647, 0.514, 0.704, 0.796, 0.447, 0.783, 0.746, 0.904, 0.678, 0.544, 0.862, 0.496, 0.581]

# %%
energy_index2 = []
for d in analysis2:
    energy_value = d['energy']
    energy_index2.append(energy_value)
print(energy_index2)
# Out:
# [0.378, 0.76, 0.451, 0.567, 0.754, 0.623, 0.809, 0.77, 0.815, 0.736, 0.924, 0.877, 0.705, 0.672, 0.781, 0.802, 0.747, 0.567, 0.868, 0.712, 0.593, 0.876, 0.821, 0.671, 0.823, 0.651, 0.499, 0.379, 0.637, 0.767, 0.608, 0.473, 0.869, 0.682, 0.553, 0.732, 0.445, 0.703, 0.678, 0.685, 0.53, 0.873, 0.521, 0.765, 0.68, 0.609, 0.717, 0.564, 0.356, 0.662]

# %%
energy_index3 = []
for d in analysis3:
    energy_value = d['energy']
    energy_index3.append(energy_value)
print(energy_index3)
# Out:
# [0.503, 0.783, 0.831, 0.811, 0.922, 0.547, 0.31, 0.757, 0.526, 0.818, 0.756, 0.359, 0.684, 0.868, 0.436, 0.44, 0.677, 0.754, 0.652, 0.28, 0.474, 0.538, 0.758, 0.512, 0.286, 0.78, 0.79, 0.923, 0.905, 0.71, 0.777, 0.867, 0.537, 0.692, 0.698, 0.422, 0.704, 0.85, 0.676, 0.465, 0.603, 0.805, 0.264, 0.915, 0.938, 0.473, 0.727, 0.715, 0.898, 0.758]

# %%
energy_index4 = []
for d in analysis4:
    energy_value = d['energy']
    energy_index4.append(energy_value)
print(energy_index4)
# Out:
# [0.298, 0.57, 0.716, 0.417, 0.822, 0.921, 0.804, 0.496, 0.548, 0.406, 0.783, 0.866, 0.872, 0.755, 0.531, 0.558, 0.807, 0.84, 0.588, 0.887, 0.754, 0.438, 0.698, 0.784, 0.313, 0.971, 0.341, 0.823, 0.915, 0.971, 0.425, 0.597, 0.904, 0.793, 0.813, 0.867, 0.439, 0.683, 0.69, 0.918, 0.623, 0.274, 0.869, 0.521, 0.86, 0.744]

# %%
speechiness_index = []
for d in analysis:
    speechiness_value = d['speechiness']
    speechiness_index.append(speechiness_value)
print(speechiness_index)
# Out:
# [0.112, 0.0842, 0.0824, 0.0924, 0.0645, 0.148, 0.0495, 0.045, 0.102, 0.0259, 0.05, 0.0287, 0.0395, 0.187, 0.122, 0.0683, 0.0435, 0.0845, 0.267, 0.401, 0.0442, 0.0489, 0.0263, 0.375, 0.0449, 0.287, 0.0319, 0.0607, 0.0493, 0.0337, 0.0748, 0.0939, 0.0318, 0.0874, 0.102, 0.0874, 0.147, 0.0524, 0.0721, 0.0476, 0.172, 0.045, 0.251, 0.0482, 0.0618, 0.0324, 0.0372, 0.0812, 0.0905, 0.159]

# %%
speechiness_index2 = []
for d in analysis2:
    speechiness_value = d['speechiness']
    speechiness_index2.append(speechiness_value)
print(speechiness_index2)
# Out:
# [0.438, 0.045, 0.0347, 0.0956, 0.067, 0.0571, 0.0625, 0.0482, 0.0581, 0.0385, 0.0359, 0.0664, 0.0543, 0.0955, 0.0567, 0.0561, 0.0428, 0.0798, 0.0731, 0.046, 0.0304, 0.244, 0.104, 0.0678, 0.0762, 0.0306, 0.118, 0.0476, 0.141, 0.102, 0.098, 0.0514, 0.0789, 0.13, 0.187, 0.0457, 0.0295, 0.0369, 0.0511, 0.0309, 0.0434, 0.128, 0.0366, 0.078, 0.0629, 0.0824, 0.318, 0.0315, 0.196, 0.174]

# %%
speechiness_index3 = []
for d in analysis3:
    speechiness_value = d['speechiness']
    speechiness_index3.append(speechiness_value)
print(speechiness_index3)
# Out:
# [0.0494, 0.0523, 0.0298, 0.038, 0.0786, 0.0489, 0.0283, 0.153, 0.293, 0.0859, 0.0415, 0.155, 0.0768, 0.0392, 0.139, 0.0249, 0.0316, 0.156, 0.232, 0.0434, 0.0313, 0.0572, 0.158, 0.0503, 0.0294, 0.0436, 0.0374, 0.173, 0.0289, 0.0461, 0.0432, 0.071, 0.04, 0.0431, 0.0431, 0.0342, 0.251, 0.0691, 0.0418, 0.0377, 0.0615, 0.0395, 0.0322, 0.0544, 0.0356, 0.167, 0.0409, 0.0407, 0.0391, 0.074]

# %%
speechiness_index4 = []
for d in analysis4:
    speechiness_value = d['speechiness']
    speechiness_index4.append(speechiness_value)
print(speechiness_index4)
# Out:
# [0.0304, 0.361, 0.0616, 0.0295, 0.0355, 0.303, 0.0409, 0.0387, 0.0658, 0.0483, 0.321, 0.0342, 0.588, 0.312, 0.122, 0.179, 0.0302, 0.255, 0.0246, 0.0358, 0.0569, 0.141, 0.042, 0.236, 0.0393, 0.233, 0.0355, 0.0726, 0.0369, 0.0694, 0.0307, 0.0764, 0.0343, 0.035, 0.0368, 0.128, 0.0396, 0.107, 0.265, 0.0807, 0.0812, 0.044, 0.0553, 0.216, 0.0832, 0.136]

# %%
tempo_index = []
for d in analysis:
    tempo_value = d['tempo']
    tempo_index.append(tempo_value)
print(tempo_index)
# Out:
# [104.0, 123.941, 97.986, 98.027, 95.927, 116.735, 104.952, 107.975, 128.038, 89.991, 151.148, 95.971, 120.042, 92.977, 107.356, 95.016, 125.058, 129.972, 132.023, 175.041, 101.956, 118.118, 108.897, 135.128, 91.845, 179.974, 109.891, 151.912, 107.019, 114.842, 143.032, 117.945, 150.073, 172.913, 136.041, 164.004, 97.981, 163.862, 96.026, 133.002, 197.705, 170.002, 143.952, 91.698, 82.014, 103.952, 129.979, 126.976, 86.003, 108.909]

# %%
tempo_index2 = []
for d in analysis2:
    tempo_value = d['tempo']
    tempo_index2.append(tempo_value)
print(tempo_index2)
# Out:
# [100.418, 99.945, 157.966, 125.02, 149.882, 134.962, 98.007, 107.951, 123.063, 103.027, 111.995, 107.991, 154.911, 111.996, 139.432, 100.001, 122.531, 135.553, 122.003, 98.022, 98.02, 100.018, 120.462, 118.413, 99.933, 90.011, 111.016, 107.989, 169.977, 113.842, 191.812, 119.992, 108.061, 167.939, 142.072, 145.992, 78.998, 138.113, 88.967, 118.016, 108.038, 148.075, 130.071, 122.916, 114.025, 114.988, 190.05, 117.973, 97.001, 99.879]

# %%
tempo_index3 = []
for d in analysis3:
    tempo_value = d['tempo']
    tempo_index3.append(tempo_value)
print(tempo_index3)
# Out:
# [119.998, 124.08, 129.889, 116.047, 146.078, 95.002, 111.893, 159.911, 94.992, 116.019, 179.771, 119.885, 130.03, 128.007, 84.804, 98.082, 124.988, 107.999, 100.315, 72.795, 79.991, 75.089, 135.956, 76.899, 134.348, 125.014, 127.946, 99.252, 125.927, 91.972, 87.016, 162.131, 122.764, 116.017, 143.994, 119.964, 171.898, 110.004, 95.017, 120.988, 127.997, 116.057, 119.93, 126.027, 126.973, 84.958, 111.009, 127.435, 126.05, 99.89]

# %%
tempo_index4 = []
for d in analysis4:
    tempo_value = d['tempo']
    tempo_index4.append(tempo_value)
print(tempo_index4)
# Out:
# [78.815, 136.203, 99.426, 134.956, 93.993, 93.058, 188.061, 115.989, 100.015, 147.912, 79.045, 149.897, 168.602, 99.595, 71.994, 83.465, 105.447, 99.876, 100.43, 101.035, 125.014, 85.013, 96.021, 124.821, 124.21, 98.159, 135.541, 87.904, 134.322, 100.264, 105.154, 147.507, 122.371, 173.976, 122.515, 170.256, 80.493, 78.96, 78.519, 117.399, 103.649, 176.466, 129.014, 95.262, 180.725, 82.356]

# %%
valence_index = []
for d in analysis:
    valence_value = d['valence']
    valence_index.append(valence_value)
print(valence_index)
# Out:
# [0.359, 0.677, 0.668, 0.513, 0.478, 0.457, 0.203, 0.283, 0.35, 0.43, 0.694, 0.397, 0.553, 0.548, 0.651, 0.678, 0.696, 0.496, 0.514, 0.762, 0.842, 0.723, 0.167, 0.562, 0.186, 0.226, 0.446, 0.247, 0.599, 0.363, 0.62, 0.867, 0.483, 0.695, 0.639, 0.353, 0.179, 0.368, 0.296, 0.628, 0.62, 0.308, 0.498, 0.576, 0.681, 0.404, 0.199, 0.623, 0.544, 0.0857]

# %%
valence_index2 = []
for d in analysis2:
    valence_value = d['valence']
    valence_index2.append(valence_value)
print(valence_index2)
# Out:
# [0.515, 0.41, 0.289, 0.793, 0.764, 0.585, 0.274, 0.593, 0.636, 0.378, 0.529, 0.752, 0.743, 0.382, 0.197, 0.343, 0.483, 0.109, 0.336, 0.799, 0.438, 0.79, 0.331, 0.55, 0.396, 0.166, 0.466, 0.201, 0.648, 0.722, 0.0789, 0.34, 0.593, 0.506, 0.656, 0.276, 0.591, 0.595, 0.212, 0.603, 0.417, 0.817, 0.327, 0.343, 0.656, 0.928, 0.603, 0.465, 0.19, 0.438]

# %%
valence_index3 = []
for d in analysis3:
    valence_value = d['valence']
    valence_index3.append(valence_value)
print(valence_index3)
# Out:
# [0.863, 0.643, 0.144, 0.862, 0.847, 0.441, 0.125, 0.962, 0.662, 0.253, 0.404, 0.154, 0.479, 0.0376, 0.331, 0.343, 0.254, 0.86, 0.759, 0.387, 0.36, 0.244, 0.542, 0.512, 0.149, 0.458, 0.638, 0.768, 0.838, 0.393, 0.329, 0.409, 0.131, 0.937, 0.867, 0.349, 0.729, 0.567, 0.425, 0.416, 0.402, 0.879, 0.331, 0.201, 0.898, 0.299, 0.468, 0.571, 0.599, 0.35]

# %%
valence_index4 = []
for d in analysis4:
    valence_value = d['valence']
    valence_index4.append(valence_value)
print(valence_index4)
# Out:
# [0.315, 0.441, 0.331, 0.482, 0.437, 0.681, 0.784, 0.967, 0.0922, 0.0504, 0.335, 0.838, 0.0727, 0.589, 0.344, 0.8, 0.712, 0.517, 0.584, 0.83, 0.425, 0.512, 0.47, 0.78, 0.326, 0.546, 0.269, 0.741, 0.811, 0.377, 0.396, 0.385, 0.678, 0.396, 0.456, 0.56, 0.432, 0.738, 0.614, 0.322, 0.773, 0.472, 0.709, 0.763, 0.433, 0.794]

# %%
#print songs
song_titles = []
for song in playlist["tracks"]["items"]:
    song_titles.append(song['track']['name'])
print(song_titles)
# Out:
# ['Own It (feat. Ed Sheeran & Burna Boy)', "Don't Start Now", 'South of the Border (feat. Camila Cabello & Cardi B)', 'Dance Monkey', 'Good as Hell (feat. Ariana Grande) - Remix', 'ROXANNE', 'Loyal (feat. Drake)', 'Orphans', 'No Idea', '10,000 Hours (with Justin Bieber)', 'Mind Is A Prison', "It's You", 'Circles', 'Beautiful People (feat. Khalid)', 'Post Malone (feat. RANI)', "fuck, i'm lonely (with Anne-Marie) - from “13 Reasons Why: Season 3”", 'Torn', 'Lalala', 'Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)', 'Camelot', "I Don't Care (with Justin Bieber)", 'Faith (with Dolly Parton) [feat. Mr. Probz]', 'Champion Of The World', 'bad guy', '16', 'Ransom', 'Someone You Loved', 'You Can\'t Stop The Girl (From Disney\'s "Maleficent: Mistress of Evil")', 'Traffic Jam', 'One More Try (from & Juliet)', "Don't Answer (feat. Wiley)", 'Ride It', 'Let Me Down Slowly', 'The Wrong Ones', 'Old Town Road (feat. Billy Ray Cyrus) - Remix', 'Write It Down', 'The London (feat. J. Cole & Travis S
# ...

# %%
song_titles2 = []
for song in playlist2["tracks"]["items"]:
    song_titles2.append(song['track']['name'])
print(song_titles2)
# Out:
# ['Love Yourself', 'Sorry', 'Hello', 'What Do You Mean?', 'Stitches', 'Hotline Bling', 'Lean On (feat. MØ & DJ Snake)', "Can't Feel My Face", 'Sugar (feat. Francesco Yates)', 'Stay', 'Adventure of a Lifetime', 'Light It Up (feat. Nyla & Fuse ODG) [Remix]', 'On My Mind', 'Me, Myself & I', 'Where Are Ü Now (with Justin Bieber)', 'Roses', 'Lay It All on Me', 'The Hills', 'How Deep Is Your Love', 'Lush Life', 'Same Old Love', 'Focus', 'Here', 'Locked Away', 'Perfect', 'Faded', 'Hands To Myself', 'Photograph', 'Stressed Out', 'I Know What You Did Last Summer', "I'll Show You", '7 Years', 'Bang My Head (feat. Sia & Fetty Wap)', 'In The Night', 'Jumpman', 'Never Forget You', 'Thinking out Loud', 'Drag Me Down', 'Good For You', 'Cheerleader - Felix Jaehn Remix Radio Edit', "Like I'm Gonna Lose You (feat. John Legend)", 'Trap Queen', 'White Iverson', 'Love Myself', 'Want to Want Me', 'Uptown Funk', '679 (feat. Remy Boyz)', "Ain't Nobody (Loves Me Better)", "Don't", 'Stole the Show']

# %%
song_titles3 = []
for song in playlist3["tracks"]["items"]:
    song_titles3.append(song['track']['name'])
print(song_titles3)
# Out:
# ['Blurred Lines', 'Wake Me Up - Radio Edit', 'This Is What It Feels Like', 'Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit', "Can't Hold Us - feat. Ray Dalton", 'Just Give Me a Reason (feat. Nate Ruess)', 'Stay', 'Happy', 'Thrift Shop (feat. Wanz)', 'Papaoutai', 'Roar', 'Sonnentanz', 'Scream & Shout', 'Animals', 'Royals', 'Read All About It, Pt. III', 'La La La', 'Watch Out For This (Bumaye) [feat. Busy Signal, the Flexican & FS Green]', 'Talk Dirty (feat. 2 Chainz)', 'When I Was Your Man', 'Ho Hey', 'Let Her Go', 'Feel This Moment (feat. Christina Aguilera)', 'Mirrors', 'With You', 'Hey Brother', 'I Could Be The One (Avicii Vs. Nicky Romero) - Nicktim / Radio Edit', 'On Top Of The World', 'I Love It (feat. Charli XCX) - Original Version', 'Diamonds', 'Burn', 'One Way or Another (Teenage Kicks)', 'Another Love', 'Treasure', 'Locked Out of Heaven', 'Wrecking Ball', 'Rosana', 'The Monster', "J'me tire", 'So Good To Me - Radio Edit', '#thatPOWER', 'Candy', 'All of Me', 
# ...

# %%
song_titles4 = []
for song in playlist4["tracks"]["items"]:
    song_titles4.append(song['track']['name'])
print(song_titles4)
# Out:
# ['Venice Bitch', 'OKRA', 'Los Ageless', 'Scott Street', 'Setting the World On Fire', 'No More Parties In LA', 'Chateau Lobby #4 (in C for Two Virgins)', 'Los Angeles', 'Norf Norf', 'Eternal Sunshine', 'Hoover Street', 'Put Your Number in My Phone', 'Crenshaw & Slauson (True Story)', 'Becky from the Block', 'Money Trees', 'Sweet Life', 'The Only Place', 'Bang It To The Curb', 'Time Spent in Los Angeles', 'Echo Park', 'California Gurls', 'Teach Me How to Dougie', 'Party In The U.S.A.', 'Welcome To Hollywood (feat. Jay-Z)', 'So Long Old Bean', 'City Of Angels', 'In California - Live', 'Beverly Hills', 'First of the Gang to Die', 'City Of Angels', 'Silverlake Babies', 'Debra', 'Malibu', 'L.A.', 'Electrolite', 'Down Rodeo', "Susan's House", 'April 29, 1992 (Miami)', 'She Said', 'Deep Kick', 'This Is How We Do It', 'Dogs Of L.A.', 'Andres', 'Regulate', 'Fountain and Fairfax - Remastered', 'It Was A Good Day']

# %%
songs_dataframe = pd.DataFrame({'Title': song_titles, 'ID': song_ids, 'Danceability': danceability_index,
                               'Energy': energy_index, 'Speechiness': speechiness_index, 'Tempo': tempo_index,
                                'Valence': valence_index})
songs_dataframe["Danceability"] = songs_dataframe["Danceability"] * 100
songs_dataframe["Energy"] = songs_dataframe["Energy"] * 100
songs_dataframe["Speechiness"] = songs_dataframe["Speechiness"] * 100
songs_dataframe["Valence"] = songs_dataframe["Valence"]*100
songs_dataframe
# Out:
#                                                 Title                      ID  \
# 0               Own It (feat. Ed Sheeran & Burna Boy)  4QPEwDdOMhY7rNS05mTyMR
# 1                                     Don't Start Now  6WrI0LAC5M1Rw2MnX2ZvEg
# 2   South of the Border (feat. Camila Cabello & Ca...  4vUmTMuQqjdnvlZmAH61Qk
# 3                                        Dance Monkey  2XU0oxnq2qxCpomAAuJY8K
# 4          Good as Hell (feat. Ariana Grande) - Remix  07Oz5StQ7GRoygNLaXs2pd
# 5                                             ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 6                                 Loyal (feat. Drake)  5bvnqVuq7UFl0txSlHpsfS
# 7                                             Orphans  6YQlCOZnlFmqeciAh58fDE
# 8                                             No Idea  3VyjsVV24RmBIbWJAeUJNu
# 9                   10,000 Hours (with Justin Bieber)  2wrJq5XKLnmhRXHIAf9xBa
# 10                                   Mind Is A Prison  4GGSmoTmc5LClrowB4SmEw
# ...

# %%
songs_dataframe2 = pd.DataFrame({'Title': song_titles2, 'ID': song_ids2, 'Danceability': danceability_index2,
                               'Energy': energy_index2, 'Speechiness': speechiness_index2, 'Tempo': tempo_index2,
                                'Valence': valence_index2})
songs_dataframe2["Danceability"] = songs_dataframe2["Danceability"] * 100
songs_dataframe2["Energy"] = songs_dataframe2["Energy"] * 100
songs_dataframe2["Speechiness"] = songs_dataframe2["Speechiness"] * 100
songs_dataframe2["Valence"] = songs_dataframe2["Valence"]*100
songs_dataframe2
# Out:
#                                           Title                      ID  \
# 0                                 Love Yourself  50kpGaPAhYJ3sGmk6vplg0
# 1                                         Sorry  09CtPGIpYB4BrO8qb1RGsF
# 2                                         Hello  0ENSn4fwAbCGeFGVUbXEU3
# 3                             What Do You Mean?  4B0JvthVoAAuygILe3n4Bs
# 4                                      Stitches  3zkWCteF82vJwv0hRLba76
# 5                                 Hotline Bling  6nmz4imkDcmtwMjocAzFSx
# 6                 Lean On (feat. MØ & DJ Snake)  0tiLDOYgY2n3qLFvq7c1QZ
# 7                            Can't Feel My Face  6RsWqX8zABZLhZydXxEFOm
# 8                 Sugar (feat. Francesco Yates)  5tf1VVWniHgryyumXyJM7w
# 9                                          Stay  7gBj0VgcuAgkXkiRRYvSmK
# 10                      Adventure of a Lifetime  69uxyAqqPIsUyTO8txoP2M
# 11  Light It Up (feat. Nyla & Fuse ODG) [Remix]  40MkEbKzuSW9ET6HBngqnK
# ...

# %%
songs_dataframe3 = pd.DataFrame({'Title': song_titles3, 'ID': song_ids3, 'Danceability': danceability_index3,
                               'Energy': energy_index3, 'Speechiness': speechiness_index3, 'Tempo': tempo_index3,
                                'Valence': valence_index3})
songs_dataframe3["Danceability"] = songs_dataframe3["Danceability"] * 100
songs_dataframe3["Energy"] = songs_dataframe3["Energy"] * 100
songs_dataframe3["Speechiness"] = songs_dataframe3["Speechiness"] * 100
songs_dataframe3["Valence"] = songs_dataframe3["Valence"]*100
songs_dataframe3
# Out:
#                                                 Title                      ID  \
# 0                                       Blurred Lines  0XzkemXSiXJa7VgDFPfU4S
# 1                             Wake Me Up - Radio Edit  6g1NlCpW7fgqDnWbCCDrHl
# 2                          This Is What It Feels Like  5GjnIpUlLGEIYk052ISOw9
# 3   Get Lucky (feat. Pharrell Williams & Nile Rodg...  2Foc5Q5nqNiosCNqttzHof
# 4                    Can't Hold Us - feat. Ray Dalton  3bidbhpOYeV4knp8AIu8Xn
# 5            Just Give Me a Reason (feat. Nate Ruess)  1mKXFLRA179hdOWQBwUk9e
# 6                                                Stay  0GNI8K3VATWBABQFAzBAYe
# 7                                               Happy  6NPVjNh8Jhru9xOmyQigds
# 8                            Thrift Shop (feat. Wanz)  1CmUZGtH29Kx36C1Hleqlz
# 9                                           Papaoutai  09TcIuH1ZO7i4vicWKoaN2
# 10                                               Roar  3bDGwl0X3EjQmIyFD1uif5
# ...

# %%
songs_dataframe4 = pd.DataFrame({'Title': song_titles4, 'ID': song_ids4, 'Danceability': danceability_index4,
                               'Energy': energy_index4, 'Speechiness': speechiness_index4, 'Tempo': tempo_index4,
                                'Valence': valence_index4})
songs_dataframe4["Danceability"] = songs_dataframe4["Danceability"] * 100
songs_dataframe4["Energy"] = songs_dataframe4["Energy"] * 100
songs_dataframe4["Speechiness"] = songs_dataframe4["Speechiness"] * 100
songs_dataframe4["Valence"] = songs_dataframe4["Valence"]*100
songs_dataframe4
# Out:
#                                       Title                      ID  \
# 0                              Venice Bitch  3hwQhakFwm9soLEBnSDH17
# 1                                      OKRA  74ZovzRxHBvCq5yIwe8boh
# 2                               Los Ageless  2qTy3hGSbxoSenKmlKGHFw
# 3                              Scott Street  0jqFM7E9z1PLYtPVCuFwAi
# 4                 Setting the World On Fire  7AclP0W2jy6yrbvBiC4prQ
# 5                     No More Parties In LA  0zLClc0emc6qUeV1p5nc99
# 6   Chateau Lobby #4 (in C for Two Virgins)  2eg2gvPXuwZ9FyrPaLgrXi
# 7                               Los Angeles  6Eh8SvUdMWJGZvTR8t0174
# 8                                 Norf Norf  4uQ7wYsuL0DryknoDc11Hk
# 9                          Eternal Sunshine  3t844ssjXzE9M3SDtUxTI4
# 10                            Hoover Street  4fUeGY1jGkgtx11tuqbDlq
# 11              Put Your Number in My Phone  0gBrJS89BL4r8rqjDEzbtp
# 12          Crenshaw & Slauson (True Story)  1a1MJ64D5ZIdzVWJ3uGaLy
# ...

# %%
merged = [songs_dataframe, songs_dataframe2, songs_dataframe3, songs_dataframe4]

result = pd.concat(merged)
result
# Out:
#                                                 Title                      ID  \
# 0               Own It (feat. Ed Sheeran & Burna Boy)  4QPEwDdOMhY7rNS05mTyMR
# 1                                     Don't Start Now  6WrI0LAC5M1Rw2MnX2ZvEg
# 2   South of the Border (feat. Camila Cabello & Ca...  4vUmTMuQqjdnvlZmAH61Qk
# 3                                        Dance Monkey  2XU0oxnq2qxCpomAAuJY8K
# 4          Good as Hell (feat. Ariana Grande) - Remix  07Oz5StQ7GRoygNLaXs2pd
# ..                                                ...                     ...
# 41                                       Dogs Of L.A.  4Q3Q7HnaHYxZ8RTwErNWAn
# 42                                             Andres  0nidu6qIs1DlnuYC4qyzvm
# 43                                           Regulate  7nYvUtkQMx1v80S2FH2s9J
# 44                  Fountain and Fairfax - Remastered  52QGQqQIxLEeMoUAzKpsue
# 45                                  It Was A Good Day  2qOm7ukLyHUXWyR4ZWLwxA
#
# ...

# %%
result.min()
# Out:
# Title                       #thatPOWER
# ID              01uqI4H13Gsd8Lyl1EYd8H
# Danceability                      17.5
# Energy                            26.4
# Speechiness                       2.46
# Tempo                           71.994
# Valence                           3.76
# dtype: object

# %%
result.max()
# Out:
# Title           fuck, i'm lonely (with Anne-Marie) - from “13 ...
# ID                                         7xMklu8GE39dYZBWJMxrBU
# Danceability                                                 92.6
# Energy                                                       97.1
# Speechiness                                                  58.8
# Tempo                                                     197.705
# Valence                                                      96.7
# dtype: object

# %%
danceability_number = int(input("Choose an integer between 15 and 95 (15 is least danceable and 95 is most danceable): "))
if danceability_number > 95 or danceability_number < 15: 
    print("Invalid entry. Please try again.")
    danceability_number = int(input("Choose an integer between 15 and 95 (15 is least danceable and 95 is most danceable): "))
energy_number = int(input("Choose an integer between 25 and 98 (25 is least energetic and 98 is most energetic): "))
if energy_number > 98 or energy_number < 25: 
    print("Invalid entry. Please try again.")
    energy_number = int(input("Choose an integer between 25 and 98 (25 is least energetic and 98 is most energetic): "))
speechiness_number = int(input("Choose an integer between 2 and 60 (2 means the song has very few to no spoken words and 60 means the song is mostly if not all spoken word): "))
if speechiness_number > 60 or speechiness_number < 2: 
    print("Invalid entry. Please try again.")
    speechiness_number = int(input("Choose an integer between 2 and 60 (2 means the song has very few to no spoken words and 60 means the song is mostly if not all spoken word): "))
tempo_number = int(input("Choose a BPM (in integer format) between 70 and 200 (70 means the song has 70 BPM and 200 means the song has 200 BPM): "))
if tempo_number > 200 or tempo_number < 70:
    print("Invalid entry. Please try again.")
    tempo_number = int(input("Choose a BPM (in integer format) between 70 and 200 (70 means the song has 70 BPM and 200 means the song has 200 BPM): "))
valence_number = int(input("Choose an integer between 3 and 100 (3 means the song sounds negative emotionally and 100 means the song sounds positive emotionally): "))
if valence_number > 100 or valence_number < 3: 
    print("Invalid entry. Please try again.")
    valence_number = int(input("Choose an integer between 3 and 100 (3 means the song sounds negative emotionally and 100 means the song sounds positive emotionally): "))

new = result[ (result['Danceability'] < danceability_number + 10) & 
                       (result['Danceability'] > danceability_number - 10) &
                      (result['Energy'] < energy_number + 10) & 
                       (result['Energy'] > energy_number - 10) &
                      (result['Speechiness'] < speechiness_number + 8) & 
                       (result['Speechiness'] > speechiness_number - 8) &
                      (result['Tempo'] < tempo_number + 10) & 
                       (result['Tempo'] > tempo_number - 10) &
                      (result['Valence'] < valence_number + 10) & 
                       (result['Valence'] > valence_number - 10)]              
new
# Out:
# Choose an integer between 15 and 95 (15 is least danceable and 95 is most danceable): 80
# Choose an integer between 25 and 98 (25 is least energetic and 98 is most energetic): 80
# Choose an integer between 2 and 60 (2 means the song has very few to no spoken words and 60 means the song is mostly if not all spoken word): 5
# Choose a BPM (in integer format) between 70 and 200 (70 means the song has 70 BPM and 200 means the song has 200 BPM): 150
# Choose an integer between 3 and 100 (3 means the song sounds negative emotionally and 100 means the song sounds positive emotionally): 70
#                          Title                      ID  Danceability  Energy  \
# 30  Don't Answer (feat. Wiley)  6dNaImQJF0Y1wrjMBy4KLz          70.1    78.9
# 4                     Stitches  3zkWCteF82vJwv0hRLba76          74.6    75.4
# 12                  On My Mind  4nS1sut0R2mgmFitKIShVe          70.2    70.5
#
#     Speechiness    Tempo  Valence
# 30         7.48  143.032     62.0
# ...
